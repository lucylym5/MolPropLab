# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": ["# MolPropLab Demo\n\nThis notebook demonstrates quick EDA and training on the toy dataset."]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": ["import pandas as pd\nfrom core import ensure_demo_dataset\n\ndf = ensure_demo_dataset('data/example.csv')\ndf.head()"],
   "execution_count": null,
   "outputs": []
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": ["from core import train_baseline_demo, train_gnn_demo\n\nprint(train_baseline_demo())\ntry:\n    print(train_gnn_demo())\nexcept Exception as e:\n    print('GNN skipped:', e)"],
   "execution_count": null,
   "outputs": []
  }
 ],
 "metadata": { "kernelspec": { "display_name": "Python 3", "language": "python", "name": "python3" } },
 "nbformat": 4,
 "nbformat_minor": 5
}
